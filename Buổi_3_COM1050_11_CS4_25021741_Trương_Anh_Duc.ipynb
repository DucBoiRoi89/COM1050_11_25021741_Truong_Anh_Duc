# %% [markdown]
# Bài 1

# %%
integer_n = input("Số nguyên cần nhập là: ")
print("Chữ số đảo ngược của n là:", int((integer_n)[::-1]))
# Out:
# Số nguyên cần nhập là: 1
# Chữ số đảo ngược của n là: 1

# %% [markdown]
# Bài 2

# %%
a, b = map(int, input().split())
a = a ^ b
b = a ^ b
a = a ^ b
print(a, b)
# Out:
# 5 5
# 5 5

# %% [markdown]
# Bài 3

# %%
n = int(input())
if n == 1:
  print("True")
else:
  base_2 = bin(n)
  if int(base_2[2]) == 1 and int(base_2[3]) == 0:
    print("True")
  else:
    print("False")
# Out:
# 192
# False

# %%
n = int(input())
base_2_n = bin(n)
base_2_n_1 = bin(n-1)
if int(base_2_n, 2) & int(base_2_n_1, 2) == 0:
  print("True")
else:
  print("False")
# Out:
# 192
# False

# %% [markdown]
# Bài 4

# %%
import math
m, n = map(float, input().split())
print(math.floor(m/n))
# Out:
# 2442 2
# 1221

# %% [markdown]
# Bài 5

# %%
import math
m, n = map(float, input().split())
print(math.ceil(m/n))
# Out:
# 2442 2
# 1221

# %% [markdown]
# Bài 6

# %%
x = int(input())
if x % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# 6
# Even

# %% [markdown]
# Bài 7

# %%
a = int(input())
b = int(input())
if a < 0 and b < 0:
  print("Yes")
else:
  print("No")
# Out:
# -121
# -12
# Yes

# %% [markdown]
# Bài 8

# %%
a = input()
b = input()
if len(a) > len(b):
  print("True")
else:
  print("False")
# Out:
# abcabc
# a
# True

# %% [markdown]
# Bài 9

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b > c and a + c > b and b + c > a:
  print("Yes")
else:
  print("No")
# Out:
# 10
# 11
# -12
# No

# %% [markdown]
# Bài 10

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = max(a, b, c, d)
print(e)
# Out:
# 99999
# 999
# 99
# 9
# 99999

# %% [markdown]
# Bài 11

# %%
a, b, c = map(int, input().split())
if a + b > c and a + c > b and b + c > a:
  if a == b == c:
    print("Tam giác đều")
  elif a == b or a == c or b == c:
    print("Tam giác cân")
  else:
    print("Tam giác thường")
else:
  print("Không phải tam giác")
# Out:
# 0 0 0
# Không phải tam giác

# %% [markdown]
# Bài 12

# %%
n = int(input())
if (n % 4 == 0 and n % 100 != 0) or n % 400 == 0:
  print("Yes")
else:
  print("No")
# Out:
# 2024
# Yes

# %% [markdown]
# Bài 13

# %%
n = int(input("Số kWh điện tiêu thụ là: "))
if 0 <= n <= 50:
  print("Tiền điện tiêu thụ là: ", n * 1500)
elif 51 <= n <= 100:
  print("Tiền điện tiêu thụ là: ", n * 2000)
else:
  print("Tiền điện tiêu thụ là: ", n * 3000)
# Out:
# Số kWh điện tiêu thụ là: 100
# Tiền điện tiêu thụ là:  200000

# %% [markdown]
# Bài 14

# %%
a = float(input())
b = float(input())
if a == 0:
  if b == 0:
    print("Vô số nghiệm")
  else:
    print("Vô nghiệm")
else:
  if b == 0:
    print("Phương trình có nghiệm là: 0")
  else:
    print("Phương trình có nghiệm là:", round(-b/a, 2))
# Out:
# 0.23
# 99.1
# Phương trình có nghiệm là: -430.87

# %% [markdown]
# Bài 15

# %%
average_score = float(input())
if average_score >= 8.0:
  print("Giỏi")
elif average_score >= 6.5:
  print("Khá")
elif average_score >= 5.0:
  print("Trung bình")
elif average_score < 5.0:
  print("Yếu")
# Out:
# 8
# Giỏi

# %% [markdown]
# Bài 16

# %%
n = float(input())
if n > 0:
  if int(((n * 10) % 10)) >= 5:
    print(int((n // 1)) + 1, int(n) // 1, int((n // 1)) + 1)
  else:
    print(int((n // 1)) + 1, int(n // 1), int(n // 1))
elif n < 0:
  if int(((-n * 10) % 10)) >= 5:
    print(int(n // 1) + 1, int(n // 1) + 1 - 1, int(n // 1) + 1 -1)
  else:
    print((int(n //1)) + 1, (int(n // 1)) + 1 - 1, (int(n // 1)) + 1)
else:
  print("0 0 0")
# Out:
# 7.4
# 8 7 7

# %% [markdown]
# Bài 17

# %%
a, b, c = map(int, input().split())
if a + b > c and a + c > b and b + c > a:
  if a == b == c:
    print("Tam giác đều")
  elif a == b or a == c or b == c:
    print("Tam giác cân")
  else:
    print("Tam giác thường")
else:
  print("Không phải tam giác")
# Out:
# 0 0 0
# Không phải tam giác
