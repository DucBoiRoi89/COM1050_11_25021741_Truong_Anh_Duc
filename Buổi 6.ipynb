# %% [markdown]
# Bài 1:

# %%
a = map(int, input().split())
a = list(a)
ds = []
c = []
total = 0
for i in range(len(a)):
    for x in range(i + 1, len(a)):
        if a[i] == a[x]:
            total += 1
            c.append(a[i])
for i in range(total):   
    for i in c:
        if i in a:
            a.remove(i)
for i in a:
    c.append(i)
print(c)
# a = map(int, input().split())
# b = []
# for i in a:
#     if i not in b:
#         b.append(i)
# print(b)

# %% [markdown]
# Bài 2:

# %%
a = map(int, input().split())
a = list(a)
ds = []
for i in range(len(a)):
    print(i)
    total = 0
    for x in range(i + 1):
        print(x)
        total += a[x]
        print(total)
    ds.append(total)
print(ds)

# %% [markdown]
# Bài 3:

# %%
a = map(int, input().split())
k = int(input())
a = list(a)
ds = []
for i in range(k, len(a)):
    ds.append(a[i])
for i in a:
    if i not in ds:
        ds.append(i)
print(tuple(ds))

# %% [markdown]
# Bài 4:

# %%
a = input().split()
ds = []
c = []
d = []
e = []
m = []
n = []
a = list(a)
for i in a:
    ds.append(i)
for i in ds:
    for x in range(len(i)):
        if i[x] == ":":
            c.append(x)
for i in range(len(ds)):
    d.append((ds[i][:int(c[i])], ds[i][int(c[i])+1:]))
for i in range(len(d)):
    for x in range(i + 1, len(d)):
        if d[i][0] == d[x][0]:
            e.append(i)
for i in range(len(d)):
    for x in range(i + 1, len(d)):
        if d[i][0] == d[x][0]:
            for y in range(len(e) - 1):
                m.append((d[i][0], [d[i][1], d[x][1]]))
# for i in range(len(ds)):
#     for x in range(len(e)):
#         if ds[i][0] != e[x]:
#             m.append((ds[i][0], ds[i][2]))
print(m)
f = {}
for i in range(len(m)):
    if type(m[i][1]) == list:
        f[m[i][0]] = m[i][1]
    else:
        f[m[i][0]] = [m[i][1]]
for i in ds:
    print(i)

# %% [markdown]
# Bài 5:

# %%
a = list(map(int, input().split()))
total1 = 0
total2 = 0
total3 = 0
for i in range(len(a)):
    if a[i] > 0:
        total1 += 1
    elif a[i] == 0:
        total2 += 1
    else:
        total3 += 1
f = {}
f['positives'] = total1
f['negatives'] = total3
f['zeros'] = total2
print(f)

# %% [markdown]
# Bài 6:

# %%
a = list(map(int, input().split()))
total = 0
for i in a:
    total += i
print(total)

# %% [markdown]
# Bài 7:

# %%
a = tuple(input().split())
a = list(a)
a = tuple(a[::-1])
print(a[len(a) - 1], a[0], a, end = " ")

# %% [markdown]
# Bài 8:

# %%
a = input()
a = list(a.split())
f = {}
for i in range(len(a)):
    f[a[i]] = a.count(a[i])
print(f)

# %% [markdown]
# Bài 9:

# %%
a = input()
b = input()
a = a.split("{")
a = a[1].split("}")
a = a[0]
b = b.split("{")
b = b[1].split("}")
b = b[0]
m = {}
n = {}
a = a.split(", ")
b = b.split(", ")
if a != [''] and b != ['']:
    for i in range(len(a)):
        a[i] = a[i].split(":")
        a[i][0] = a[i][0].split("'")
        a[i][0] = a[i][0][1]
        a[i][0] = a[i][0].split("'")
        a[i][0] = a[i][0][0]
        m.update({a[i][0]: int(a[i][1])})
    for i in range(len(b)):
        print(b[i])
        b[i] = b[i].split(":")
        b[i][0] = b[i][0].split("'")
        b[i][0] = b[i][0][1]
        b[i][0] = b[i][0].split("'")
        b[i][0] = b[i][0][0]
        n.update({b[i][0]: int(b[i][1])})
    for i, x in n.items():
        if i not in m.keys():
            m[i] = n[i]
        else:
            x = int(x)
            m[i] = int(m[i]) + x
    print(m)
else:
    if a == ['']:
        for i in range(len(b)):
            print(b[i])
            b[i] = b[i].split(":")
            b[i][0] = b[i][0].split("'")
            b[i][0] = b[i][0][1]
            b[i][0] = b[i][0].split("'")
            b[i][0] = b[i][0][0]
            n.update({b[i][0]: int(b[i][1])})
            print(n)
    if b == ['']:
        for i in range(len(a)):
            print(a[i])
            a[i] = a[i].split(":")
            a[i][0] = a[i][0].split("'")
            a[i][0] = a[i][0][1]
            a[i][0] = a[i][0].split("'")
            a[i][0] = a[i][0][0]
            m.update({a[i][0]: int(a[i][1])})
            print(m)

# %% [markdown]
# Bài 10:

# %%
a = map(int, input().split())
k = int(input())
m = []
a = list(a)
for i in range(len(a)):
    for x in range(i + 1, len(a)):
        total = a[i] + a[x]
        if total == k:
            m.append((a[i], a[x]))
n = []
for i in m:
    if i not in n:
        n.append(i)
print(n)
# Out:
# [(1, 3)]

# %% [markdown]
# Bài 11:

# %%
a = tuple(map(int, input().split()))
a = list(a)
m = []
n = []
for i in range(len(a)):
    if a[i] % 2 == 0:
        m.append(a[i])
    else:
        n.append(a[i])
m = tuple(m)
n = tuple(n)
print(m)
print(n)

# %% [markdown]
# Bài 12:

# %%
a = list(map(int, input().split()))
m = []
n = []
for i in a:
    m.append([i, a.count(i)])
total = 0
for i in range(len(m)):
    for x in range(len(m)):
        if m[i][1] >= m[x][1]:
            total = m[i][1]
        else:
            total = m[x][1]
for i in range(len(m)):
    if m[i][1] == total:
        n.append(m[i][0])
print(min(n))

# %% [markdown]
# Bài 13:

# %%
a = input().split()
a = list(a)
m = {}
for i in range(0, len(a), 2):
    m[a[i + 1]] = a[i]
print(m)

# %% [markdown]
# Bài 14:

# %%
a = list(map(int, input().split()))
b = list(map(int, input().split()))
c = []
d = []
for i in a:
    if i in b:
        c.append(i)
for i in c:
    if i not in d:
        d.append(i)
print(d)

# %% [markdown]
# Bài 15:

# %%
a = list(map(str, input().split()))
b = int(input())
c = {}
for i in range(0, len(a), 2):
    c[a[i]] = int(a[i + 1])
for i in range(0, len(a), 2):
    if c[a[i]] <= b:
        c.pop(a[i])
print(c)

# %% [markdown]
# Bài 16:

# %%
n = int(input())
m = int(input())
while True:
    a = list(map(int, input().split()))
    if m * n == len(a):
        break
ds = []
for i in range(0, len(a), m):
    b = a[i:i+m]
    print(b)
#     ds.append(b)
# print(ds)

# %% [markdown]
# Bài 17:

# %%
while True:
    a = map(int, input().split())
    a = list(a)
    n = int(len(a) ** 0.5)
    if int(n ** 2) == len(a):
        break
ds = []
for i in range(0, len(a), n):
    b = a[i:i+n]
    ds.append(b)
c = []
for i in range(n):
    c.append(ds[i][i])
d = []
for i in range(n):
    d.append(ds[i][n - i - 1])
print(c)
print(d)

# %% [markdown]
# Bài 18:

# %%
while True:
    n, m, k = map(int, input().split())
    if k <=n and k <= m:
        break
a = list(map(int, input().split()))
ds = []
for i in range(0, len(a), m):
    ds.append(a[i:i+m])
total = 0
for i in range(m):
    total += ds[k- 1][i]
for i in range(n):
    total += ds[i][k - 1]
print(total)

# %% [markdown]
# Bài 19:

# %%
a = map(int, input().split())
a = list(a)
print(a.index(max(a)))

# %% [markdown]
# Bài 20:

# %%
a = map(int, input().split())
while True:
    k = int(input())
    if k > 0:
        break
a = list(a)
ds = []
if k in a:
    ds.append(a.index(k))
if len(ds) > 0:
    print(min(ds) + 1)
else:
    print("-1")

# %% [markdown]
# Bài 21:

# %%
a = list(map(str, input().split()))
c = []
for i, x in enumerate(a):
    c.append((x, i))
ds = {}
for i in range(len(c)):
    if c[i][0] not in ds:
        d = [c[i][1]]
        d = tuple(d)
        ds[c[i][0]] = d
    else:
        d = list(ds[c[i][0]])
        d.append(c[i][1])
        d = tuple(d)
        ds[c[i][0]] = d
print(ds)

# %% [markdown]
# Bài 22:

# %%
a = list(map(int, input().split()))
ds = []
for i in range(len(a)):
    if a[i] == max(a):
        ds.append(i + 1)
print(min(ds))
